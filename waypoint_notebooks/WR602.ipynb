# %%
import numpy as np
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth

from planet import api
from planet.api import filters
from sys import stdout
import json
import io
import tempfile

from datetime import date, datetime, timedelta
import time
import os
import pathlib
import fnmatch

# %%
geojson_geometry = {
    "type": "Point",
    "coordinates": [
         -118.300073,35.386440
        ]
}

# get images that overlap with our AOI 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# %%
# Generating time parameters
today = datetime.isoformat(datetime.utcnow())+'Z'#(datetime.today())
start_date = datetime.isoformat(datetime.utcnow() - timedelta(7)) + 'Z'

# %%
# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": start_date,
    "lte": today
  }
}

# only get images which have <10% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.1
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %%
# Generating Order

# API Key stored as an env variable
PL_API_KEY = 'XXXXXXXXXXXXXXXX'
PLANET_API_KEY = PL_API_KEY #os.getenv('PL_API_KEY')
orders_url = 'https://api.planet.com/compute/ops/orders/v2'

# set up requests to work with api
auth = HTTPBasicAuth(PLANET_API_KEY, '')
headers = {'content-type': 'application/json'}

item_type = "PSScene4Band"

# API request object
search_request = {
    "interval": "day",
    "item_types": [item_type],
    "asset_types" : "analytic_sr",
    "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
#     'https://api.planet.com/data/v2',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/7c8daa8e58564e6592617715fe1f2faa/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/7c8daa8e58564e6592617715fe1f2faa/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTAyLTE2VDAwOjA0OjIwLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwMjE1XzE4MTYzN18xMDM5IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/7c8daa8e58564e6592617715fe1f2faa/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181819_1004",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181819_1004/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181819_1004/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.30509874871485,
#        35.35488879083034
#       ],
#       [
#        -118.58167678995287,
#        35.4032388331559
#       ],
#       [
#        -118.56546683687115,
#        35.46485690469674
#       ],
#       [
#        -118.56529734505806,
#        35.46482727030459
#       ],
#       [
#        -118.56233883094417,
#        35.476417216838634
#       ],
#       [
#        -118.28583250663876,
#        35.42800322354675
#       ],
#       [
#        -118.29055337807667,
#        35.40963807611049
#       ],
#       [
#        -118.29057664587349,
#        35.40955177892437
#       ],
#       [
#        -118.29072786848383,
#        35.40957816303866
#       ],
#       [
#        -118.30509874871485,
#        35.35488879083034
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200220_181819_1004",
#    "properties": {
#     "acquired": "2020-02-20T18:18:19.006108Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 98,
#     "clear_percent": 98,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "columns": 8968,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 356373,
#     "origin_y": 3927000,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-21T00:08:47Z",
#     "quality_category": "standard",
#     "rows": 4607,
#     "satellite_id": "1004",
#     "shadow_percent": 0,
#     "snow_ice_percent": 2,
#     "strip_id": "3158452",
#     "sun_azimuth": 145.7,
#     "sun_elevation": 37,
#     "updated": "2020-02-21T04:22:13Z",
#     "view_angle": 0.1,
#     "visible_confidence_percent": 81,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_181636_1039",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_181636_1039/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_181636_1039/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.47908595050642,
#        35.410100799920144
#       ],
#       [
#        -118.46623030799175,
#        35.45928062736325
#       ],
#       [
#        -118.18821408210214,
#        35.41109257402663
#       ],
#       [
#        -118.19128069864301,
#        35.399460602837195
#       ],
#       [
#        -118.190747924778,
#        35.39936876460174
#       ],
#       [
#        -118.19210777562729,
#        35.39406719875708
#       ],
#       [
#        -118.20684038083715,
#        35.338150915426425
#       ],
#       [
#        -118.48502263648699,
#        35.386128054920235
#       ],
#       [
#        -118.47908595050642,
#        35.410100799920144
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_181636_1039",
#    "properties": {
#     "acquired": "2020-02-19T18:16:36.331752Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 96,
#     "clear_percent": 93,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 8999,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 365121,
#     "origin_y": 3924966,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-20T00:04:41Z",
#     "quality_category": "standard",
#     "rows": 4585,
#     "satellite_id": "1039",
#     "shadow_percent": 0,
#     "snow_ice_percent": 7,
#     "strip_id": "3155462",
#     "sun_azimuth": 145.8,
#     "sun_elevation": 36.7,
#     "updated": "2020-02-20T04:28:20Z",
#     "view_angle": 2.9,
#     "visible_confidence_percent": 77,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200218_181748_100c",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200218_181748_100c/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200218_181748_100c/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.41396093098791,
#        35.39438720824654
#       ],
#       [
#        -118.41209801715566,
#        35.401473868218645
#       ],
#       [
#        -118.4116080826983,
#        35.40138786269616
#       ],
#       [
#        -118.40856851037279,
#        35.413312666647904
#       ],
#       [
#        -118.1314430582082,
#        35.364861684198694
#       ],
#       [
#        -118.1457789424234,
#        35.30883268804202
#       ],
#       [
#        -118.15028048710555,
#        35.29190182235523
#       ],
#       [
#        -118.42769771948215,
#        35.340619839392296
#       ],
#       [
#        -118.41396093098791,
#        35.39438720824654
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200218_181748_100c",
#    "properties": {
#     "acquired": "2020-02-18T18:17:48.520533Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 93,
#     "clear_percent": 100,
#     "cloud_cover": 0.04,
#     "cloud_percent": 0,
#     "columns": 8986,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 370257,
#     "origin_y": 3919791,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-19T00:26:57Z",
#     "quality_category": "standard",
#     "rows": 4590,
#     "satellite_id": "100c",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3151662",
#     "sun_azimuth": 145.8,
#     "sun_elevation": 36.3,
#     "updated": "2020-02-19T04:04:18Z",
#     "view_angle": 2,
#     "visible_confidence_percent": 93,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200217_163839_1048",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200217_163839_1048/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200217_163839_1048/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.2745768628886,
#        35.345148985825254
#       ],
#       [
#        -118.52173491829753,
#        35.30452026415327
#       ],
#       [
#        -118.53756887502013,
#        35.36984690867805
#       ],
#       [
#        -118.29077207774554,
#        35.41024827897572
#       ],
#       [
#        -118.2883190377229,
#        35.40008623547181
#       ],
#       [
#        -118.28791112819862,
#        35.4001533139985
#       ],
#       [
#        -118.2745768628886,
#        35.345148985825254
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200217_163839_1048",
#    "properties": {
#     "acquired": "2020-02-17T16:38:39.909535Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 90,
#     "clear_percent": 99,
#     "cloud_cover": 0.02,
#     "cloud_percent": 0,
#     "columns": 7954,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 360321,
#     "origin_y": 3919305,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-17T22:11:50Z",
#     "quality_category": "standard",
#     "rows": 3810,
#     "satellite_id": "1048",
#     "shadow_percent": 1,
#     "snow_ice_percent": 0,
#     "strip_id": "3147980",
#     "sun_azimuth": 123.7,
#     "sun_elevation": 21.7,
#     "updated": "2020-02-18T04:43:18Z",
#     "view_angle": 0,
#     "visible_confidence_percent": 70,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_181637_1039",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_181637_1039/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200215_181637_1039/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.38437815697117,
#        35.418280901625494
#       ],
#       [
#        -118.10833539472063,
#        35.370729439983165
#       ],
#       [
#        -118.1269057253113,
#        35.29794915716288
#       ],
#       [
#        -118.4037899561342,
#        35.34560766830344
#       ],
#       [
#        -118.38794330485364,
#        35.40693115694377
#       ],
#       [
#        -118.38735333294167,
#        35.40682961392779
#       ],
#       [
#        -118.38437815697117,
#        35.418280901625494
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200215_181637_1039",
#    "properties": {
#     "acquired": "2020-02-15T18:16:37.221532Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 93,
#     "clear_percent": 100,
#     "cloud_cover": 0.03,
#     "cloud_percent": 0,
#     "columns": 8961,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 372438,
#     "origin_y": 3920313,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-16T00:04:20Z",
#     "quality_category": "standard",
#     "rows": 4549,
#     "satellite_id": "1039",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3141687",
#     "sun_azimuth": 146.5,
#     "sun_elevation": 35.5,
#     "updated": "2020-02-16T04:32:47Z",
#     "view_angle": 1.9,
#     "visible_confidence_percent": 93,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]

# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
#print(result.json().keys())

# %%
# Parse out useful links
links = result.json()[u"analytic_sr"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'visual' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
# # Activation Status if needed
# activation_status_result = \
#   requests.get(
#     self_link,
#     auth=HTTPBasicAuth(PLANET_API_KEY, '')
#   )

# %% [markdown]
# ## Ordering from V2
# * https://api.planet.com/compute/ops/orders/v2
# * https://github.com/planetlabs/notebooks/blob/d92943e82a87de7653452a99084c4a16a877babf/jupyter-notebooks/orders/tools_and_toolchains.ipynb

# %%
# define products part of order
single_product = [
    {
      "item_ids": [id0],#["20151119_025740_0c74"],
      "item_type": "PSScene4Band",
      "product_bundle": "analytic_sr"
    }
]

# %%
# define helpful functions for submitting, polling, and downloading an order
def place_order(request, auth):
    response = requests.post(orders_url, data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    
    if not response.ok:
        raise Exception(response.content)

    order_id = response.json()['id']
    print(order_id)
    order_url = orders_url + '/' + order_id
    return order_url

def poll_for_success(order_url, auth, num_loops=50):
    count = 0
    while(count < num_loops):
        count += 1
        r = requests.get(order_url, auth=auth)
        response = r.json()
        state = response['state']
        print(state)
        success_states = ['success', 'partial']
        if state == 'failed':
            raise Exception(response)
        elif state in success_states:
            break
        
        time.sleep(10)
        
def download_order(order_url, auth, overwrite=False):
    r = requests.get(order_url, auth=auth)
    print(r)

    response = r.json()
    results = response['_links']['results']
    results_urls = [r['location'] for r in results]
    results_names = [r['name'] for r in results]
    results_paths = [pathlib.Path(os.path.join('data', n)) for n in results_names]
    print('{} items to download'.format(len(results_urls)))
    
    for url, name, path in zip(results_urls, results_names, results_paths):
        if overwrite or not path.exists():
            print('downloading {} to {}'.format(name, path))
            r = requests.get(url, allow_redirects=True)
            path.parent.mkdir(parents=True, exist_ok=True)
            open(path, 'wb').write(r.content)
        else:
            print('{} already exists, skipping {}'.format(path, name))
            
    return dict(zip(results_names, results_paths))

# %% [markdown]
# ### Clip
# <a id='clip'></a>
#
# Clipping is likely the most common tool that will be used. It allows us to only download the pixels we are interested in.

# %%
clip_aoi = {
    "type":"Polygon",
    "coordinates":[[[-118.304073, 35.38244],
                    [-118.304073, 35.39044],
                    [-118.29607299999999, 35.39044],
                    [-118.29607299999999, 35.38244],
                    [-118.304073, 35.38244]]]
}

# define the clip tool
clip = {
    "clip": {
        "aoi": clip_aoi
    }
}

# create an order request with the clipping tool
request_clip = {
  "name": "just clip",
  "products": single_product,
  "tools": [clip]
}

# %%
def place_order(request, auth):
    response = requests.post(orders_url, data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    order_id = response.json()['id']
    print(order_id)
    order_url = orders_url + '/' + order_id
    return order_url

order_url = place_order(request_clip, auth)
# Out:
# <Response [202]>
# a831f43d-78ec-4bca-9d30-12a2cb623a88

# %%
# Pulling specific image
#r = requests.get(order_url, auth=auth)
response = requests.get(order_url, auth=auth).json()
#response = r.json()
results = response['_links']['results']
results_name = [r['name'] for r in results]
pattern = '*SR_clip.tif'
results_sr = fnmatch.filter(results_name, pattern)

# %%
# allow for caching so we don't always run clip
run_clip = True

clip_img_file = results_sr[0]
if os.path.isfile(clip_img_file): run_clip = False

# %%
if run_clip:
    clip_order_url = place_order(request_clip, auth)
    poll_for_success(clip_order_url, auth)
#     downloaded_clip_files = download_order(clip_order_url, auth)
#     clip_img_file = next(downloaded_clip_files[d] for d in downloaded_clip_files
#                      if d.endswith('_SR.tif'))
#downloaded_clip_files = download_order(clip_order_url, auth)
#clip_img_file
# Out:
# <Response [202]>
# 0efc04d4-a431-457a-a39e-d702c1c282c1
# queued
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# success

# %%
download_order(clip_order_url, auth)
# Out:
# <Response [200]>
# 5 items to download
# downloading 0efc04d4-a431-457a-a39e-d702c1c282c1/1/manifest.json to data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/manifest.json
# downloading 0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_metadata_clip.xml to data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_metadata_clip.xml
# downloading 0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_metadata.json to data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_metadata.json
# downloading 0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_DN_udm_clip.tif to data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_DN_udm_clip.tif
# downloading 0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_SR_clip.tif to data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_SR_clip.tif
# {'0efc04d4-a431-457a-a39e-d702c1c282c1/1/manifest.json': PosixPath('data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/manifest.json'),
#  '0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_metadata_clip.xml': PosixPath('data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_metadata_clip.xml'),
#  '0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_metadata.json': PosixPath('data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_metadata.json'),
#  '0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_DN_udm_clip.tif': PosixPath('data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_DN_udm_clip.tif'),
#  '0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_SR_clip.tif': PosixPath('data/0efc04d4-a431-457a-a39e-d702c1c282c1/1/files/20200220_181819_1004_3B_AnalyticMS_SR_clip.tif')}
