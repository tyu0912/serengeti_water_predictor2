# %%
import numpy as np
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth

from planet import api
from planet.api import filters
from sys import stdout
import json
import io
import tempfile

from datetime import date, datetime, timedelta
import time
import os
import pathlib
import fnmatch

# %%
geojson_geometry = {
    "type": "Point",
    "coordinates": [
         -118.468572,34.979435
        ]
}

# get images that overlap with our AOI 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# %%
# Generating time parameters
today = datetime.isoformat(datetime.utcnow())+'Z'#(datetime.today())
start_date = datetime.isoformat(datetime.utcnow() - timedelta(7)) + 'Z'

# %%
# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": start_date,
    "lte": today
  }
}

# only get images which have <10% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.1
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %%
# Generating Order

# API Key stored as an env variable
PL_API_KEY = 'XXXXXXXXX'
PLANET_API_KEY = PL_API_KEY #os.getenv('PL_API_KEY')
orders_url = 'https://api.planet.com/compute/ops/orders/v2'

# set up requests to work with api
auth = HTTPBasicAuth(PLANET_API_KEY, '')
headers = {'content-type': 'application/json'}

item_type = "PSScene4Band"

# API request object
search_request = {
    "interval": "day",
    "item_types": [item_type],
    "asset_types" : "analytic_sr",
    "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
#     'https://api.planet.com/data/v2',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/6a55a38492674289834a1a3adc7520c4/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/6a55a38492674289834a1a3adc7520c4/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTAyLTE2VDAwOjA0OjIwLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwMjE1XzE4MTY0M18xMDM5IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/6a55a38492674289834a1a3adc7520c4/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181825_1004",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181825_1004/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181825_1004/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.6779812386398,
#        35.03036025330729
#       ],
#       [
#        -118.66478904766306,
#        35.080866781336034
#       ],
#       [
#        -118.38924976243204,
#        35.03245989552192
#       ],
#       [
#        -118.3924324740041,
#        35.020477224497355
#       ],
#       [
#        -118.3922333627091,
#        35.02044232667358
#       ],
#       [
#        -118.39556980164586,
#        35.00743199047454
#       ],
#       [
#        -118.40821821974862,
#        34.95920737711864
#       ],
#       [
#        -118.68379211612863,
#        35.00753276244983
#       ],
#       [
#        -118.6779812386398,
#        35.03036025330729
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200220_181825_1004",
#    "properties": {
#     "acquired": "2020-02-20T18:18:25.270826Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 8973,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 346356,
#     "origin_y": 3883281,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-21T00:08:47Z",
#     "quality_category": "standard",
#     "rows": 4619,
#     "satellite_id": "1004",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3158452",
#     "sun_azimuth": 145.4,
#     "sun_elevation": 37.3,
#     "updated": "2020-02-21T04:22:29Z",
#     "view_angle": 0,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_181642_1039",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_181642_1039/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_181642_1039/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.57330779737262,
#        35.042963894551306
#       ],
#       [
#        -118.57082284602434,
#        35.05264277220047
#       ],
#       [
#        -118.5698768069577,
#        35.05247973780573
#       ],
#       [
#        -118.56699498608506,
#        35.064595976224965
#       ],
#       [
#        -118.29088519345528,
#        35.01688173248326
#       ],
#       [
#        -118.30124245411436,
#        34.97602527648488
#       ],
#       [
#        -118.30961720798328,
#        34.94390490996652
#       ],
#       [
#        -118.58623259206963,
#        34.99159028671979
#       ],
#       [
#        -118.57330779737262,
#        35.042963894551306
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_181642_1039",
#    "properties": {
#     "acquired": "2020-02-19T18:16:42.582313Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 97,
#     "clear_percent": 99,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 8999,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 355230,
#     "origin_y": 3881331,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-20T00:04:41Z",
#     "quality_category": "standard",
#     "rows": 4576,
#     "satellite_id": "1039",
#     "shadow_percent": 0,
#     "snow_ice_percent": 1,
#     "strip_id": "3155462",
#     "sun_azimuth": 145.5,
#     "sun_elevation": 37,
#     "updated": "2020-02-20T04:29:32Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 83,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163944_0f46",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163944_0f46/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163944_0f46/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.41256391406786,
#        34.98675474428034
#       ],
#       [
#        -118.65680134194575,
#        34.946429015797484
#       ],
#       [
#        -118.67252661716547,
#        35.01126084343533
#       ],
#       [
#        -118.42821896641377,
#        35.05154567780598
#       ],
#       [
#        -118.42596241532587,
#        35.041968275414646
#       ],
#       [
#        -118.42592455689702,
#        35.04197451920886
#       ],
#       [
#        -118.41256391406786,
#        34.98675474428034
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_163944_0f46",
#    "properties": {
#     "acquired": "2020-02-19T16:39:44.212202Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 94,
#     "clear_percent": 100,
#     "cloud_cover": 0.04,
#     "cloud_percent": 0,
#     "columns": 7895,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 347391,
#     "origin_y": 3879693,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-19T20:17:10Z",
#     "quality_category": "standard",
#     "rows": 3780,
#     "satellite_id": "0f46",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3154713",
#     "sun_azimuth": 123.1,
#     "sun_elevation": 22.4,
#     "updated": "2020-02-20T04:11:09Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 76,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163943_0f46",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163943_0f46/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163943_0f46/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.39773556143759,
#        34.92776341211593
#       ],
#       [
#        -118.64209807110211,
#        34.88738147206213
#       ],
#       [
#        -118.65768074921078,
#        34.95212289187081
#       ],
#       [
#        -118.413940948527,
#        34.99244605224176
#       ],
#       [
#        -118.41163238352307,
#        34.98290471193687
#       ],
#       [
#        -118.41113219377327,
#        34.982987284011784
#       ],
#       [
#        -118.39773556143759,
#        34.92776341211593
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_163943_0f46",
#    "properties": {
#     "acquired": "2020-02-19T16:39:43.281591Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 97,
#     "clear_percent": 100,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 7901,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 348636,
#     "origin_y": 3873120,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-19T20:17:10Z",
#     "quality_category": "standard",
#     "rows": 3779,
#     "satellite_id": "0f46",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3154713",
#     "sun_azimuth": 123.1,
#     "sun_elevation": 22.5,
#     "updated": "2020-02-20T04:10:36Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 73,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_183424_71_106e",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_183424_71_106e/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200215_183424_71_106e/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.67144319789728,
#        35.05383438311417
#       ],
#       [
#        -118.63139120864378,
#        34.898472778649705
#       ],
#       [
#        -118.34806496625022,
#        34.94726810042807
#       ],
#       [
#        -118.38765297760206,
#        35.10288617412364
#       ],
#       [
#        -118.67144319789728,
#        35.05383438311417
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200215_183424_71_106e",
#    "properties": {
#     "acquired": "2020-02-15T18:34:24.716633Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 9779,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 347568,
#     "origin_y": 3885336,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-16T04:32:22Z",
#     "quality_category": "test",
#     "rows": 7446,
#     "satellite_id": "106e",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3142240",
#     "sun_azimuth": 150.6,
#     "sun_elevation": 37.4,
#     "updated": "2020-02-16T04:35:47Z",
#     "view_angle": 1.1,
#     "visible_confidence_percent": 77,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_181643_1039",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_181643_1039/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200215_181643_1039/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.48735457307788,
#        35.02450863152153
#       ],
#       [
#        -118.2124295990733,
#        34.97712032774613
#       ],
#       [
#        -118.2308625981389,
#        34.90425017026323
#       ],
#       [
#        -118.50648817000123,
#        34.95181808421869
#       ],
#       [
#        -118.49070536201218,
#        35.01292924309365
#       ],
#       [
#        -118.49022866954193,
#        35.01284704106024
#       ],
#       [
#        -118.48735457307788,
#        35.02450863152153
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200215_181643_1039",
#    "properties": {
#     "acquired": "2020-02-15T18:16:43.453743Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "columns": 8963,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 362442,
#     "origin_y": 3876774,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-16T00:04:20Z",
#     "quality_category": "standard",
#     "rows": 4553,
#     "satellite_id": "1039",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3141687",
#     "sun_azimuth": 146.2,
#     "sun_elevation": 35.8,
#     "updated": "2020-02-16T04:32:59Z",
#     "view_angle": 2,
#     "visible_confidence_percent": 98,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]

# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
#print(result.json().keys())

# %%
# Parse out useful links
links = result.json()[u"analytic_sr"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'visual' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
# # Activation Status if needed
# activation_status_result = \
#   requests.get(
#     self_link,
#     auth=HTTPBasicAuth(PLANET_API_KEY, '')
#   )

# %% [markdown]
# ## Ordering from V2
# * https://api.planet.com/compute/ops/orders/v2
# * https://github.com/planetlabs/notebooks/blob/d92943e82a87de7653452a99084c4a16a877babf/jupyter-notebooks/orders/tools_and_toolchains.ipynb

# %%
# define products part of order
single_product = [
    {
      "item_ids": [id0],#["20151119_025740_0c74"],
      "item_type": "PSScene4Band",
      "product_bundle": "analytic_sr"
    }
]

# %%
# define helpful functions for submitting, polling, and downloading an order
def place_order(request, auth):
    response = requests.post(orders_url, data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    
    if not response.ok:
        raise Exception(response.content)

    order_id = response.json()['id']
    print(order_id)
    order_url = orders_url + '/' + order_id
    return order_url

def poll_for_success(order_url, auth, num_loops=50):
    count = 0
    while(count < num_loops):
        count += 1
        r = requests.get(order_url, auth=auth)
        response = r.json()
        state = response['state']
        print(state)
        success_states = ['success', 'partial']
        if state == 'failed':
            raise Exception(response)
        elif state in success_states:
            break
        
        time.sleep(10)
        
def download_order(order_url, auth, overwrite=False):
    r = requests.get(order_url, auth=auth)
    print(r)

    response = r.json()
    results = response['_links']['results']
    results_urls = [r['location'] for r in results]
    results_names = [r['name'] for r in results]
    results_paths = [pathlib.Path(os.path.join('data', n)) for n in results_names]
    print('{} items to download'.format(len(results_urls)))
    
    for url, name, path in zip(results_urls, results_names, results_paths):
        if overwrite or not path.exists():
            print('downloading {} to {}'.format(name, path))
            r = requests.get(url, allow_redirects=True)
            path.parent.mkdir(parents=True, exist_ok=True)
            open(path, 'wb').write(r.content)
        else:
            print('{} already exists, skipping {}'.format(path, name))
            
    return dict(zip(results_names, results_paths))

# %% [markdown]
# ### Clip
# <a id='clip'></a>
#
# Clipping is likely the most common tool that will be used. It allows us to only download the pixels we are interested in.

# %%
clip_aoi = {
    "type":"Polygon",
    "coordinates":[[[-118.472572, 34.975435],
                    [-118.472572, 34.98343499999999],
                    [-118.46457199999999, 34.98343499999999],
                    [-118.46457199999999, 34.975435],
                    [-118.472572,34.975435]]]
}

# define the clip tool
clip = {
    "clip": {
        "aoi": clip_aoi
    }
}

# create an order request with the clipping tool
request_clip = {
  "name": "just clip",
  "products": single_product,
  "tools": [clip]
}

# %%
def place_order(request, auth):
    response = requests.post(orders_url, data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    order_id = response.json()['id']
    print(order_id)
    order_url = orders_url + '/' + order_id
    return order_url

order_url = place_order(request_clip, auth)
# Out:
# <Response [202]>
# 35801c07-da38-4535-908d-862cb09e917c

# %%
# Pulling specific image
response = requests.get(order_url, auth=auth).json()
#response = r.json()
results = response['_links']['results']
results_name = [r['name'] for r in results]
pattern = '*SR_clip.tif'
results_sr = fnmatch.filter(results_name, pattern)

# %%
# allow for caching so we don't always run clip
run_clip = True

clip_img_file = results_sr[0]
if os.path.isfile(clip_img_file): run_clip = False

# %%
if run_clip:
    clip_order_url = place_order(request_clip, auth)
    poll_for_success(clip_order_url, auth)
#     downloaded_clip_files = download_order(clip_order_url, auth)
#     clip_img_file = next(downloaded_clip_files[d] for d in downloaded_clip_files
#                      if d.endswith('_SR.tif'))
downloaded_clip_files = download_order(clip_order_url, auth)
clip_img_file
# Out:
# <Response [202]>
# 2c1731fa-295b-4eed-8c26-0701a47c54f2
# queued
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# success
# <Response [200]>
# 5 items to download
# downloading 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_metadata.json to data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_metadata.json
# downloading 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/manifest.json to data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/manifest.json
# downloading 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif to data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif
# downloading 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_metadata_clip.xml to data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_metadata_clip.xml
# downloading 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_DN_udm_clip.tif to data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_DN_udm_clip.tif
# '35801c07-da38-4535-908d-862cb09e917c/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif'

# %%
download_order(clip_order_url, auth)
# Out:
# <Response [200]>
# 5 items to download
# data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_metadata.json already exists, skipping 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_metadata.json
# data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/manifest.json already exists, skipping 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/manifest.json
# data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif already exists, skipping 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif
# data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_metadata_clip.xml already exists, skipping 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_metadata_clip.xml
# data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_DN_udm_clip.tif already exists, skipping 2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_DN_udm_clip.tif
# {'2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_metadata.json': PosixPath('data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_metadata.json'),
#  '2c1731fa-295b-4eed-8c26-0701a47c54f2/1/manifest.json': PosixPath('data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/manifest.json'),
#  '2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif': PosixPath('data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_SR_clip.tif'),
#  '2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_metadata_clip.xml': PosixPath('data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_metadata_clip.xml'),
#  '2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_DN_udm_clip.tif': PosixPath('data/2c1731fa-295b-4eed-8c26-0701a47c54f2/1/files/20200220_181825_1004_3B_AnalyticMS_DN_udm_clip.tif')}
