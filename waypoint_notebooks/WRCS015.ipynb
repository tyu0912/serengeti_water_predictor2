# %%
import numpy as np
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth

from planet import api
from planet.api import filters
from sys import stdout
import json
import io
import tempfile

from datetime import date, datetime, timedelta
import time
import os
import pathlib
import fnmatch

# %%
geojson_geometry = {
    "type": "Point",
    "coordinates": [
         -116.545505,32.661418
        ]
}

# get images that overlap with our AOI 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# %%
# Generating time parameters
today = datetime.isoformat(datetime.utcnow())+'Z'#(datetime.today())
start_date = datetime.isoformat(datetime.utcnow() - timedelta(7)) + 'Z'

# %%
# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": start_date,
    "lte": today
  }
}

# only get images which have <10% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.1
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %%
# Generating Order

# API Key stored as an env variable
PL_API_KEY = 'XXXXXXXXXXX'
PLANET_API_KEY = PL_API_KEY #os.getenv('PL_API_KEY')
orders_url = 'https://api.planet.com/compute/ops/orders/v2'

# set up requests to work with api
auth = HTTPBasicAuth(PLANET_API_KEY, '')
headers = {'content-type': 'application/json'}

item_type = "PSScene4Band"

# API request object
search_request = {
    "interval": "day",
    "item_types": [item_type],
    "asset_types" : "analytic_sr",
    "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
#     'https://api.planet.com/data/v2',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/608c4a2404d94fc5b5f3647247fa1339/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/608c4a2404d94fc5b5f3647247fa1339/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTAyLTE2VDAwOjAxOjI5LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwMjE1XzE4MDg0OV8xMDI1IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/608c4a2404d94fc5b5f3647247fa1339/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181002_1034",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181002_1034/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200220_181002_1034/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.71000694791677,
#        32.703100628419705
#       ],
#       [
#        -116.70982762600684,
#        32.703813417267355
#       ],
#       [
#        -116.70947665721262,
#        32.7037508358038
#       ],
#       [
#        -116.7065075024376,
#        32.7159012034277
#       ],
#       [
#        -116.43842430983901,
#        32.66822128661203
#       ],
#       [
#        -116.4546525194751,
#        32.60222857379134
#       ],
#       [
#        -116.45654082937695,
#        32.59478805935029
#       ],
#       [
#        -116.72477556178188,
#        32.642598368431514
#       ],
#       [
#        -116.71000694791677,
#        32.703100628419705
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200220_181002_1034",
#    "properties": {
#     "acquired": "2020-02-20T18:10:02.555075Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 76,
#     "clear_percent": 85,
#     "cloud_cover": 0.07,
#     "cloud_percent": 0,
#     "columns": 8948,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 5,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 10,
#     "origin_x": 525813,
#     "origin_y": 3619833,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-20T23:07:47Z",
#     "quality_category": "standard",
#     "rows": 4446,
#     "satellite_id": "1034",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3158418",
#     "sun_azimuth": 144,
#     "sun_elevation": 39.1,
#     "updated": "2020-02-21T04:29:13Z",
#     "view_angle": 1.9,
#     "visible_confidence_percent": 57,
#     "visible_percent": 95
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_182852_62_106d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_182852_62_106d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_182852_62_106d/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.79486498562629,
#        32.727357604528834
#       ],
#       [
#        -116.75663159664643,
#        32.572066528017984
#       ],
#       [
#        -116.48114856958514,
#        32.62011851727881
#       ],
#       [
#        -116.51919979324144,
#        32.775599566024596
#       ],
#       [
#        -116.79486498562629,
#        32.727357604528834
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_182852_62_106d",
#    "properties": {
#     "acquired": "2020-02-19T18:28:52.621433Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 9819,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 519219,
#     "origin_y": 3626514,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-20T13:04:22Z",
#     "quality_category": "standard",
#     "rows": 7547,
#     "satellite_id": "106d",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3155885",
#     "sun_azimuth": 149.5,
#     "sun_elevation": 40.9,
#     "updated": "2020-02-20T13:08:11Z",
#     "view_angle": 2.1,
#     "visible_confidence_percent": 84,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163142_0f33",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163142_0f33/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_163142_0f33/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.73463127420318,
#        32.64276919366308
#       ],
#       [
#        -116.7384426382986,
#        32.65943418642256
#       ],
#       [
#        -116.49800129002641,
#        32.700429014272444
#       ],
#       [
#        -116.49533914144887,
#        32.68912827254606
#       ],
#       [
#        -116.49476372054532,
#        32.689227401148756
#       ],
#       [
#        -116.48987725462403,
#        32.669021486751454
#       ],
#       [
#        -116.48198417675742,
#        32.63539260268738
#       ],
#       [
#        -116.72279912825039,
#        32.59398358018942
#       ],
#       [
#        -116.7346180821554,
#        32.642771484535
#       ],
#       [
#        -116.73463127420318,
#        32.64276919366308
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_163142_0f33",
#    "properties": {
#     "acquired": "2020-02-19T16:31:42.657738Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 95,
#     "clear_percent": 100,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 8022,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 524526,
#     "origin_y": 3618189,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-20T00:03:53Z",
#     "quality_category": "standard",
#     "rows": 3960,
#     "satellite_id": "0f33",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3155543",
#     "sun_azimuth": 122.6,
#     "sun_elevation": 24,
#     "updated": "2020-02-20T04:26:40Z",
#     "view_angle": 4.9,
#     "visible_confidence_percent": 95,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_180702_1001",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200219_180702_1001/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200219_180702_1001/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.66172554107037,
#        32.70499241745879
#       ],
#       [
#        -116.65138707180232,
#        32.74686355282821
#       ],
#       [
#        -116.38423824242479,
#        32.699828590425525
#       ],
#       [
#        -116.38693274158929,
#        32.68909159410961
#       ],
#       [
#        -116.38579054018611,
#        32.68889175848505
#       ],
#       [
#        -116.39336043705559,
#        32.65778461090032
#       ],
#       [
#        -116.40100928136518,
#        32.62722460109781
#       ],
#       [
#        -116.669077513321,
#        32.67412585889326
#       ],
#       [
#        -116.66172554107037,
#        32.70499241745879
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200219_180702_1001",
#    "properties": {
#     "acquired": "2020-02-19T18:07:02.2887Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 85,
#     "clear_percent": 99,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 8898,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 531024,
#     "origin_y": 3623280,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-19T22:11:19Z",
#     "quality_category": "standard",
#     "rows": 4387,
#     "satellite_id": "1001",
#     "shadow_percent": 0,
#     "snow_ice_percent": 1,
#     "strip_id": "3155032",
#     "sun_azimuth": 143.9,
#     "sun_elevation": 38.7,
#     "updated": "2020-02-20T04:24:48Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 73,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200218_180841_0f22",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200218_180841_0f22/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200218_180841_0f22/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.55296662723224,
#        32.60180703394038
#       ],
#       [
#        -116.8246546226179,
#        32.64914608222686
#       ],
#       [
#        -116.80622293798163,
#        32.72314297241019
#       ],
#       [
#        -116.53487885903418,
#        32.67538768871297
#       ],
#       [
#        -116.53807874293356,
#        32.662689897901515
#       ],
#       [
#        -116.53777070156737,
#        32.66263623251363
#       ],
#       [
#        -116.55296662723224,
#        32.60180703394038
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200218_180841_0f22",
#    "properties": {
#     "acquired": "2020-02-18T18:08:41.381874Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 96,
#     "clear_percent": 100,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 9055,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 516444,
#     "origin_y": 3620613,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-19T00:27:35Z",
#     "quality_category": "standard",
#     "rows": 4461,
#     "satellite_id": "0f22",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3151623",
#     "sun_azimuth": 144.6,
#     "sun_elevation": 38.6,
#     "updated": "2020-02-19T06:02:01Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 96,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200216_181009_1034",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200216_181009_1034/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200216_181009_1034/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.73623996160687,
#        32.73202050282476
#       ],
#       [
#        -116.4692563905065,
#        32.68445263665269
#       ],
#       [
#        -116.4872267753373,
#        32.611149678722846
#       ],
#       [
#        -116.754759695092,
#        32.65893144847947
#       ],
#       [
#        -116.73999060208911,
#        32.719460287515474
#       ],
#       [
#        -116.73934652250058,
#        32.71934522421148
#       ],
#       [
#        -116.73623996160687,
#        32.73202050282476
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200216_181009_1034",
#    "properties": {
#     "acquired": "2020-02-16T18:10:09.022542Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 97,
#     "clear_percent": 100,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 8920,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 522996,
#     "origin_y": 3621612,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-16T22:11:01Z",
#     "quality_category": "standard",
#     "rows": 4439,
#     "satellite_id": "1034",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3144977",
#     "sun_azimuth": 144.8,
#     "sun_elevation": 37.8,
#     "updated": "2020-02-17T04:24:31Z",
#     "view_angle": 2,
#     "visible_confidence_percent": 97,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_180849_1025",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200215_180849_1025/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200215_180849_1025/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.64712675492245,
#        32.70866998146046
#       ],
#       [
#        -116.37962667648029,
#        32.66081295648552
#       ],
#       [
#        -116.39791160656708,
#        32.587568546869335
#       ],
#       [
#        -116.66518496438952,
#        32.63557643450343
#       ],
#       [
#        -116.65005197578976,
#        32.697099524105454
#       ],
#       [
#        -116.64997025244072,
#        32.69708484246614
#       ],
#       [
#        -116.64712675492245,
#        32.70866998146046
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200215_180849_1025",
#    "properties": {
#     "acquired": "2020-02-15T18:08:49.805165Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 96,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "columns": 8923,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 531405,
#     "origin_y": 3619047,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-16T00:01:29Z",
#     "quality_category": "standard",
#     "rows": 4441,
#     "satellite_id": "1025",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3141586",
#     "sun_azimuth": 144.7,
#     "sun_elevation": 37.3,
#     "updated": "2020-02-16T04:36:23Z",
#     "view_angle": 3.1,
#     "visible_confidence_percent": 75,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]

# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
#print(result.json().keys())

# %%
# Parse out useful links
links = result.json()[u"analytic_sr"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'visual' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
# # Activation Status if needed
# activation_status_result = \
#   requests.get(
#     self_link,
#     auth=HTTPBasicAuth(PLANET_API_KEY, '')
#   )

# %% [markdown]
# ## Ordering from V2
# * https://api.planet.com/compute/ops/orders/v2
# * https://github.com/planetlabs/notebooks/blob/d92943e82a87de7653452a99084c4a16a877babf/jupyter-notebooks/orders/tools_and_toolchains.ipynb

# %%
# define products part of order
single_product = [
    {
      "item_ids": [id0],#["20151119_025740_0c74"],
      "item_type": "PSScene4Band",
      "product_bundle": "analytic_sr"
    }
]

# %%
# define helpful functions for submitting, polling, and downloading an order
def place_order(request, auth):
    response = requests.post(orders_url, data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    
    if not response.ok:
        raise Exception(response.content)

    order_id = response.json()['id']
    print(order_id)
    order_url = orders_url + '/' + order_id
    return order_url

def poll_for_success(order_url, auth, num_loops=50):
    count = 0
    while(count < num_loops):
        count += 1
        r = requests.get(order_url, auth=auth)
        response = r.json()
        state = response['state']
        print(state)
        success_states = ['success', 'partial']
        if state == 'failed':
            raise Exception(response)
        elif state in success_states:
            break
        
        time.sleep(10)
        
def download_order(order_url, auth, overwrite=False):
    r = requests.get(order_url, auth=auth)
    print(r)

    response = r.json()
    results = response['_links']['results']
    results_urls = [r['location'] for r in results]
    results_names = [r['name'] for r in results]
    results_paths = [pathlib.Path(os.path.join('data', n)) for n in results_names]
    print('{} items to download'.format(len(results_urls)))
    
    for url, name, path in zip(results_urls, results_names, results_paths):
        if overwrite or not path.exists():
            print('downloading {} to {}'.format(name, path))
            r = requests.get(url, allow_redirects=True)
            path.parent.mkdir(parents=True, exist_ok=True)
            open(path, 'wb').write(r.content)
        else:
            print('{} already exists, skipping {}'.format(path, name))
            
    return dict(zip(results_names, results_paths))

# %% [markdown]
# ### Clip
# <a id='clip'></a>
#
# Clipping is likely the most common tool that will be used. It allows us to only download the pixels we are interested in.

# %%
clip_aoi = {
    "type":"Polygon",
    "coordinates":[[[-116.54950500000001,32.657418],
                    [-116.54950500000001, 32.665417999999995],
                    [-116.541505, 32.665417999999995],
                    [-116.541505, 32.657418],
                    [-116.54950500000001, 32.657418]]]
}

# define the clip tool
clip = {
    "clip": {
        "aoi": clip_aoi
    }
}

# create an order request with the clipping tool
request_clip = {
  "name": "just clip",
  "products": single_product,
  "tools": [clip]
}

# %%
def place_order(request, auth):
    response = requests.post(orders_url, data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    order_id = response.json()['id']
    print(order_id)
    order_url = orders_url + '/' + order_id
    return order_url

order_url = place_order(request_clip, auth)
# Out:
# <Response [202]>
# c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910

# %%
# Pulling specific image
#r = requests.get(order_url, auth=auth)
response = requests.get(order_url, auth=auth).json()
#response = r.json()
results = response['_links']['results']
results_name = [r['name'] for r in results]
pattern = '*SR_clip.tif'
results_sr = fnmatch.filter(results_name, pattern)

# %%
requests.get(order_url, auth=auth).json()
# Out:
# {'_links': {'_self': 'https://api.planet.com/compute/ops/orders/v2/c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910',
#   'results': [{'delivery': 'success',
#     'expires_at': '2020-02-23T02:28:32.347Z',
#     'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....5WE0SQW1fSN7l8ShqJU_0SVFHY5RnMWpy3qWqsVqBuOlLRJqhDAv7Clg58dkLrtWNr-6nI9YcZPQTZ8VbFgldg',
#     'name': 'c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910/1/files/20200220_181002_1034_3B_AnalyticMS_DN_udm_clip.tif'},
#    {'delivery': 'success',
#     'expires_at': '2020-02-23T02:28:32.355Z',
#     'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....DhwRd909U3iVfmSY6WpBlt1etUIkWCoMUGUm8CiNj6d9V51W66JoET3yct1vzyymvvZ57ZlF9W5YPqtxzJzFuQ',
#     'name': 'c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910/1/files/20200220_181002_1034_metadata.json'},
#    {'delivery': 'success',
#     'expires_at': '2020-02-23T02:28:32.343Z',
#     'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....K0YaDo38jmT7C_QrFN52wn4kVkTWsmJA2mbZCS9eqvGhxa0vIRY5kY3OKky1_fQKrpNCe-yUyw4bn0GEgVs5-g',
#     'name': 'c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910/1/manifest.json'},
#    {'delivery': 'success',
#     'expires_at': '2020-02-23T02:28:32.351Z',
#     'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....EAlBuxv38n2xTooUKGVBttvdnmg4pGVee53rbXeG6hwze8WBpcFyn_CdwnuyxjQgSsPiESvOrY2S-D5Isv_0Ew',
#     'name': 'c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910/1/files/20200220_181002_1034_3B_AnalyticMS_metadata_clip.xml'},
#    {'delivery': 'success',
#     'expires_at': '2020-02-23T02:28:32.359Z',
#     'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....dubh3de7m7Dy2q-IdI1_0IuvEIK6ry1N5cGnDtdK5pptG1OcWHCDvhtYDNOBPic6a0T3HZzlE4MkRuJQ7Nkwxg',
#     'name': 'c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910/1/files/20200220_181002_1034_3B_AnalyticMS_SR_clip.tif'}]},
#  'created_on': '2020-02-22T02:27:02.906Z',
#  'error_hints': [],
#  'id': 'c9fa4eec-e0f8-4bb8-9c8e-5364ba0e2910',
#  'last_message': 'Delivery completed',
#  'last_modified': '2020-02-22T02:29:37.217Z',
#  'name': 'just clip',
#  'products': [{'item_ids': ['20200220_181002_1034'],
#    'item_type': 'PSScene4Band',
#    'product_bundle': 'analytic_sr'}],
#  'state': 'success',
#  'tools': [{'clip': {'aoi': {'coordinates': [[[-116.54950500000001, 32.657418],
#        [-116.54950500000001, 32.665417999999995],
#        [-116.541505, 32.665417999999995],
#        [-116.541505, 32.657418],
#        [-116.54950500000001, 32.657418]]],
#      'type': 'Polygon'}}}]}

# %%
# allow for caching so we don't always run clip
run_clip = True

clip_img_file = results_sr[0]
if os.path.isfile(clip_img_file): run_clip = False

# %%
if run_clip:
    clip_order_url = place_order(request_clip, auth)
    poll_for_success(clip_order_url, auth)
#     downloaded_clip_files = download_order(clip_order_url, auth)
#     clip_img_file = next(downloaded_clip_files[d] for d in downloaded_clip_files
#                      if d.endswith('_SR.tif'))
downloaded_clip_files = download_order(clip_order_url, auth)
clip_img_file
# Out:
# <Response [202]>
# 69b0af13-5aa6-4f8b-bc90-bb85971072e0
# queued
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# success
# <Response [429]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-63-5841fe504fa1> in <module>
#       2     clip_order_url = place_order(request_clip, auth)
#       3     poll_for_success(clip_order_url, auth)
# ----> 4     downloaded_clip_files = download_order(clip_order_url, auth)
#       5 #     clip_img_file = next(downloaded_clip_files[d] for d in downloaded_clip_files
#       6 #                      if d.endswith('_SR.tif'))
#
# <ipython-input-16-6cbe379ad2ad> in download_order(order_url, auth, overwrite)
#      32     print(r)
#      33
# ---> 34     response = r.json()
#      35     results = response['_links']['results']
#      36     results_urls = [r['location'] for r in results]
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
download_order(clip_order_url, auth)
# Out:
# <Response [200]>
# 5 items to download
# downloading 69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_DN_udm_clip.tif to data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_DN_udm_clip.tif
# downloading 69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/manifest.json to data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/manifest.json
# downloading 69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_metadata_clip.xml to data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_metadata_clip.xml
# downloading 69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_metadata.json to data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_metadata.json
# downloading 69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_SR_clip.tif to data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_SR_clip.tif
# {'69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_DN_udm_clip.tif': PosixPath('data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_DN_udm_clip.tif'),
#  '69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/manifest.json': PosixPath('data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/manifest.json'),
#  '69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_metadata_clip.xml': PosixPath('data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_metadata_clip.xml'),
#  '69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_metadata.json': PosixPath('data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_metadata.json'),
#  '69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_SR_clip.tif': PosixPath('data/69b0af13-5aa6-4f8b-bc90-bb85971072e0/1/files/20200220_181002_1034_3B_AnalyticMS_SR_clip.tif')}
