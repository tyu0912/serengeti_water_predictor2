# %%
from planet import api
from planet.api import filters
from sys import stdout

# %% [markdown]
# # Querying the Planet API
# ### Step 1: Establish the query polygon

# %%
geojson_geometry = {
    "type": "Polygon",
    "coordinates": [
        [
            [-116.30126953125, 33.22030778968541],
            [-116.3671875, 34.298068350990825],
            [-117.366943359375, 34.51560953848204],
            [-118.311767578125, 34.72355492704221],
            [-118.41064453125, 34.96699890670367],
            [-118.10302734374999, 35.55010533588552],
            [-118.070068359375, 36.19995805932895],
            [-118.531494140625, 36.19995805932895],
            [-118.795166015625, 35.27253175660236],
            [-118.740234375, 34.66935854524543],
            [-118.443603515625, 34.352506668675936],
            [-117.72949218749999, 34.17999758688084],
            [-117.09228515624999, 34.17999758688084],
            [-116.93847656250001, 33.8430453147447],
            [-116.83959960937499, 33.15594830078649],
            [-116.30126953125, 33.22030778968541]
        ]
    ]
}

# %% [markdown]
# ### Step 2: Creating Filters

# %%
# get images that overlap with our AOI 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# %%
from datetime import date, datetime, timedelta

today = datetime.isoformat(datetime.utcnow())+'Z'#(datetime.today())
start_date = datetime.isoformat(datetime.utcnow() - timedelta(3)) + 'Z'


print("Today's date:", today)
print("Start date:", start_date)
# Out:
# Today's date: 2020-02-07T19:18:33.338345Z
# Start date: 2020-02-04T19:18:33.338782Z

# %%
# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": start_date,
    "lte": today
  }
}

# only get images which have <10% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.1
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %% [markdown]
# ## Step 3: Run the query

# %%
import os
import json
import requests
from requests.auth import HTTPBasicAuth

# API Key stored as an env variable
PLANET_API_KEY = os.getenv('PL_API_KEY')

item_type = "PSScene4Band"

# API request object
search_request = {
  "interval": "day",
  "item_types": [item_type], 
  "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/af40ce0650a24e11b1511423fdc8096e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/af40ce0650a24e11b1511423fdc8096e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTAyLTA1VDIwOjIxOjExLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwMjA1XzE2MzYzNV8xMDUzIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/af40ce0650a24e11b1511423fdc8096e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164211_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164211_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164211_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.51981709569284,
#        35.43610862681302
#       ],
#       [
#        -118.29528147048833,
#        35.51425422915524
#       ],
#       [
#        -118.26082880110415,
#        35.44472370954225
#       ],
#       [
#        -118.4980576825471,
#        35.36374068250816
#       ],
#       [
#        -118.51837479123513,
#        35.40659776928043
#       ],
#       [
#        -118.5076163452206,
#        35.41033891121651
#       ],
#       [
#        -118.51981709569284,
#        35.43610862681302
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164211_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:11.985652Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 81,
#     "clear_percent": 95,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 7842,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 362046,
#     "origin_y": 3930846,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T12:04:05Z",
#     "quality_category": "standard",
#     "rows": 5479,
#     "satellite_id": "0f24",
#     "shadow_percent": 2,
#     "snow_ice_percent": 3,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.5,
#     "updated": "2020-02-07T12:10:32Z",
#     "view_angle": 19.6,
#     "visible_confidence_percent": 65,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164211_1_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164211_1_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164211_1_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.5071865070137,
#        35.38299710468425
#       ],
#       [
#        -118.28380603532284,
#        35.46085798541701
#       ],
#       [
#        -118.24892479620966,
#        35.38995072495432
#       ],
#       [
#        -118.48591387351377,
#        35.30820575931184
#       ],
#       [
#        -118.50713274197278,
#        35.35323504642433
#       ],
#       [
#        -118.49504597636786,
#        35.35738776315148
#       ],
#       [
#        -118.5071865070137,
#        35.38299710468425
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164211_1_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:11.058186Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 86,
#     "clear_percent": 99,
#     "cloud_cover": 0.06,
#     "cloud_percent": 0,
#     "columns": 7838,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 363060,
#     "origin_y": 3924912,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T12:04:04Z",
#     "quality_category": "standard",
#     "rows": 5559,
#     "satellite_id": "0f24",
#     "shadow_percent": 1,
#     "snow_ice_percent": 0,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.5,
#     "updated": "2020-02-07T12:10:15Z",
#     "view_angle": 19.4,
#     "visible_confidence_percent": 65,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164210_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164210_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164210_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.49519944913554,
#        35.32791099719882
#       ],
#       [
#        -118.27028611421557,
#        35.4063796053068
#       ],
#       [
#        -118.2356262229492,
#        35.3357171071848
#       ],
#       [
#        -118.47515184397804,
#        35.256518709192264
#       ],
#       [
#        -118.49512423152025,
#        35.29852398019221
#       ],
#       [
#        -118.48328212558535,
#        35.302620836944016
#       ],
#       [
#        -118.49519944913554,
#        35.32791099719882
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164210_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:10.130721Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 85,
#     "clear_percent": 99,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 7883,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 364059,
#     "origin_y": 3918852,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T12:04:04Z",
#     "quality_category": "standard",
#     "rows": 5455,
#     "satellite_id": "0f24",
#     "shadow_percent": 2,
#     "snow_ice_percent": 0,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.5,
#     "updated": "2020-02-07T12:10:20Z",
#     "view_angle": 19.5,
#     "visible_confidence_percent": 68,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164212_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164212_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164212_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.53321279271717,
#        35.49023426872485
#       ],
#       [
#        -118.3058244154079,
#        35.56655270527795
#       ],
#       [
#        -118.2720788201542,
#        35.49884190925215
#       ],
#       [
#        -118.51018612897231,
#        35.41575788352127
#       ],
#       [
#        -118.53140005785545,
#        35.46057246113242
#       ],
#       [
#        -118.52091531567281,
#        35.464180860795075
#       ],
#       [
#        -118.53321279271717,
#        35.49023426872485
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164212_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:12.913117Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 76,
#     "clear_percent": 91,
#     "cloud_cover": 0.07,
#     "cloud_percent": 0,
#     "columns": 7901,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 360924,
#     "origin_y": 3936660,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T10:24:42Z",
#     "quality_category": "standard",
#     "rows": 5488,
#     "satellite_id": "0f24",
#     "shadow_percent": 5,
#     "snow_ice_percent": 4,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.4,
#     "updated": "2020-02-07T10:28:25Z",
#     "view_angle": 19.6,
#     "visible_confidence_percent": 64,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164209_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164209_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164209_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.4843259567421,
#        35.275813402529444
#       ],
#       [
#        -118.2581032106027,
#        35.3508221746998
#       ],
#       [
#        -118.22442288581199,
#        35.28220820091732
#       ],
#       [
#        -118.46196993882204,
#        35.203499221217754
#       ],
#       [
#        -118.48234955523748,
#        35.246902822267685
#       ],
#       [
#        -118.47219917571718,
#        35.250308754062544
#       ],
#       [
#        -118.4843259567421,
#        35.275813402529444
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164209_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:09.203255Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 78,
#     "clear_percent": 97,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 7884,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 365001,
#     "origin_y": 3912678,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T10:24:41Z",
#     "quality_category": "standard",
#     "rows": 5363,
#     "satellite_id": "0f24",
#     "shadow_percent": 3,
#     "snow_ice_percent": 0,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.6,
#     "updated": "2020-02-07T12:10:51Z",
#     "view_angle": 19.3,
#     "visible_confidence_percent": 65,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_181042_0f3f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_181042_0f3f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_181042_0f3f/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.4526114365347,
#        33.93452612971656
#       ],
#       [
#        -116.43553530305293,
#        34.00082367115774
#       ],
#       [
#        -116.16559426810893,
#        33.952693685519975
#       ],
#       [
#        -116.16862104814962,
#        33.94132331473758
#       ],
#       [
#        -116.16819988029793,
#        33.941247982200466
#       ],
#       [
#        -116.18373932725586,
#        33.88034771980476
#       ],
#       [
#        -116.45407969951248,
#        33.92865576338403
#       ],
#       [
#        -116.4526114365347,
#        33.93452612971656
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_181042_0f3f",
#    "properties": {
#     "acquired": "2020-02-06T18:10:42.596495Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "columns": 8882,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 550455,
#     "origin_y": 3762393,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T10:24:12Z",
#     "quality_category": "standard",
#     "rows": 4402,
#     "satellite_id": "0f3f",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3111146",
#     "sun_azimuth": 147.6,
#     "sun_elevation": 34,
#     "updated": "2020-02-07T10:29:09Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 98,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_181040_0f3f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_181040_0f3f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_181040_0f3f/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.15058804370034,
#        34.01133575680143
#       ],
#       [
#        -116.421180441663,
#        34.05970505894172
#       ],
#       [
#        -116.40228954644306,
#        34.1318355856262
#       ],
#       [
#        -116.1313731813224,
#        34.08357860683164
#       ],
#       [
#        -116.13644741745756,
#        34.06493169041131
#       ],
#       [
#        -116.13646444445226,
#        34.064934745372135
#       ],
#       [
#        -116.15058804370034,
#        34.01133575680143
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_181040_0f3f",
#    "properties": {
#     "acquired": "2020-02-06T18:10:40.525034Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "columns": 8909,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 553413,
#     "origin_y": 3776937,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T10:24:12Z",
#     "quality_category": "standard",
#     "rows": 4400,
#     "satellite_id": "0f3f",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3111146",
#     "sun_azimuth": 147.7,
#     "sun_elevation": 33.9,
#     "updated": "2020-02-07T10:29:07Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 99,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164213_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164213_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164213_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.548526247864,
#        35.54328083035936
#       ],
#       [
#        -118.31841807896608,
#        35.61954895120246
#       ],
#       [
#        -118.28439274784527,
#        35.55147152634925
#       ],
#       [
#        -118.52343566886735,
#        35.46950877526769
#       ],
#       [
#        -118.54479839809443,
#        35.51477316565842
#       ],
#       [
#        -118.53626429624028,
#        35.517658426468614
#       ],
#       [
#        -118.548526247864,
#        35.54328083035936
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164213_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:13.840583Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 77,
#     "clear_percent": 97,
#     "cloud_cover": 0.07,
#     "cloud_percent": 0,
#     "columns": 7986,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 359628,
#     "origin_y": 3942555,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T06:15:39Z",
#     "quality_category": "standard",
#     "rows": 5459,
#     "satellite_id": "0f24",
#     "shadow_percent": 3,
#     "snow_ice_percent": 0,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.4,
#     "updated": "2020-02-07T06:17:48Z",
#     "view_angle": 19.8,
#     "visible_confidence_percent": 64,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164208_0f24",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164208_0f24/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_164208_0f24/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -118.4707411953283,
#        35.22219053445143
#       ],
#       [
#        -118.24641761104957,
#        35.29736498739339
#       ],
#       [
#        -118.21290939735994,
#        35.228876091493085
#       ],
#       [
#        -118.45006895614566,
#        35.148823129118554
#       ],
#       [
#        -118.47087487036165,
#        35.19365908616497
#       ],
#       [
#        -118.45917915558097,
#        35.19757930170963
#       ],
#       [
#        -118.4707411953283,
#        35.22219053445143
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_164208_0f24",
#    "properties": {
#     "acquired": "2020-02-06T16:42:08.27579Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 83,
#     "clear_percent": 100,
#     "cloud_cover": 0.06,
#     "cloud_percent": 0,
#     "columns": 7846,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.7,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 366090,
#     "origin_y": 3906735,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T06:15:39Z",
#     "quality_category": "standard",
#     "rows": 5409,
#     "satellite_id": "0f24",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3111287",
#     "sun_azimuth": 127.1,
#     "sun_elevation": 18.6,
#     "updated": "2020-02-07T10:28:47Z",
#     "view_angle": 19.4,
#     "visible_confidence_percent": 67,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182707_40_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182707_40_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182707_40_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.8800779809976,
#        34.309787557878664
#       ],
#       [
#        -116.84103354048011,
#        34.156100983523665
#       ],
#       [
#        -116.56355410231912,
#        34.204471031763084
#       ],
#       [
#        -116.60218623974518,
#        34.35844701500568
#       ],
#       [
#        -116.8800779809976,
#        34.309787557878664
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182707_40_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:27:07.407523Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 94,
#     "clear_percent": 98,
#     "cloud_cover": 0.1,
#     "cloud_percent": 0,
#     "columns": 9726,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 511032,
#     "origin_y": 3801975,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7500,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 2,
#     "strip_id": "3111308",
#     "sun_azimuth": 152.1,
#     "sun_elevation": 35.4,
#     "updated": "2020-02-07T05:01:45Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182705_33_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182705_33_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182705_33_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.84813347323426,
#        34.17993376686844
#       ],
#       [
#        -116.808984191756,
#        34.026161478236645
#       ],
#       [
#        -116.53180508087793,
#        34.07445328033371
#       ],
#       [
#        -116.57041569461444,
#        34.22837228648992
#       ],
#       [
#        -116.84813347323426,
#        34.17993376686844
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182705_33_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:27:05.331867Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 93,
#     "clear_percent": 92,
#     "cloud_cover": 0.09,
#     "cloud_percent": 0,
#     "columns": 9736,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 513993,
#     "origin_y": 3787563,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7497,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 8,
#     "strip_id": "3111308",
#     "sun_azimuth": 152,
#     "sun_elevation": 35.5,
#     "updated": "2020-02-07T05:01:56Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 80,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182703_25_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182703_25_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182703_25_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.81511818327648,
#        34.04986062701126
#       ],
#       [
#        -116.77682108368025,
#        33.89585422335995
#       ],
#       [
#        -116.4994246350154,
#        33.944304047949814
#       ],
#       [
#        -116.5379977621629,
#        34.09839756475093
#       ],
#       [
#        -116.81511818327648,
#        34.04986062701126
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182703_25_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:27:03.256211Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 94,
#     "clear_percent": 99,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 9732,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 517062,
#     "origin_y": 3773163,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7511,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 1,
#     "strip_id": "3111308",
#     "sun_azimuth": 152,
#     "sun_elevation": 35.7,
#     "updated": "2020-02-07T05:01:38Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182701_18_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182701_18_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182701_18_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.78237309532823,
#        33.91927323556196
#       ],
#       [
#        -116.74280000174373,
#        33.765325816809906
#       ],
#       [
#        -116.46634472254969,
#        33.813450456818366
#       ],
#       [
#        -116.50481393225095,
#        33.96769022116913
#       ],
#       [
#        -116.78237309532823,
#        33.91927323556196
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182701_18_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:27:01.18003Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 92,
#     "clear_percent": 96,
#     "cloud_cover": 0.07,
#     "cloud_percent": 0,
#     "columns": 9758,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 520116,
#     "origin_y": 3758685,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7507,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 4,
#     "strip_id": "3111308",
#     "sun_azimuth": 152,
#     "sun_elevation": 35.8,
#     "updated": "2020-02-07T05:02:35Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182659_10_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182659_10_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182659_10_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.74777072505894,
#        33.78849616177307
#       ],
#       [
#        -116.7090974393945,
#        33.634657582089375
#       ],
#       [
#        -116.43306620613407,
#        33.68276252240689
#       ],
#       [
#        -116.47130889425353,
#        33.83699921692403
#       ],
#       [
#        -116.74777072505894,
#        33.78849616177307
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182659_10_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:26:59.104374Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 94,
#     "clear_percent": 98,
#     "cloud_cover": 0.1,
#     "cloud_percent": 0,
#     "columns": 9734,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 523350,
#     "origin_y": 3744210,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7508,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 2,
#     "strip_id": "3111308",
#     "sun_azimuth": 152,
#     "sun_elevation": 35.9,
#     "updated": "2020-02-07T05:01:52Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 77,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182657_02_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182657_02_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182657_02_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.71386933832038,
#        33.65840276996974
#       ],
#       [
#        -116.67514358587927,
#        33.50445922635297
#       ],
#       [
#        -116.39951448321038,
#        33.55271241315143
#       ],
#       [
#        -116.4376150036091,
#        33.70675011293637
#       ],
#       [
#        -116.71386933832038,
#        33.65840276996974
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182657_02_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:26:57.028718Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 97,
#     "clear_percent": 100,
#     "cloud_cover": 0.09,
#     "cloud_percent": 0,
#     "columns": 9739,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 526527,
#     "origin_y": 3729786,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7509,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3111308",
#     "sun_azimuth": 152,
#     "sun_elevation": 36,
#     "updated": "2020-02-07T05:02:30Z",
#     "view_angle": 0.9,
#     "visible_confidence_percent": 97,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182654_95_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182654_95_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182654_95_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.68060837871688,
#        33.52744481343942
#       ],
#       [
#        -116.64191815983126,
#        33.373498468076
#       ],
#       [
#        -116.36665414358623,
#        33.421620884685716
#       ],
#       [
#        -116.4047335402379,
#        33.575575428948156
#       ],
#       [
#        -116.68060837871688,
#        33.52744481343942
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182654_95_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:26:54.953062Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 97,
#     "clear_percent": 100,
#     "cloud_cover": 0.08,
#     "cloud_percent": 0,
#     "columns": 9743,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 529656,
#     "origin_y": 3715257,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:28Z",
#     "quality_category": "test",
#     "rows": 7502,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3111308",
#     "sun_azimuth": 152,
#     "sun_elevation": 36.2,
#     "updated": "2020-02-07T05:01:23Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182652_87_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182652_87_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182652_87_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.64718290589798,
#        33.39701011743423
#       ],
#       [
#        -116.60891389305823,
#        33.24301102807316
#       ],
#       [
#        -116.33380034386441,
#        33.29107287604285
#       ],
#       [
#        -116.37190376843292,
#        33.44513091739057
#       ],
#       [
#        -116.64718290589798,
#        33.39701011743423
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200206_182652_87_1063",
#    "properties": {
#     "acquired": "2020-02-06T18:26:52.876881Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0.08,
#     "cloud_percent": 0,
#     "columns": 9741,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 532809,
#     "origin_y": 3700815,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-07T04:58:27Z",
#     "quality_category": "test",
#     "rows": 7507,
#     "satellite_id": "1063",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3111308",
#     "sun_azimuth": 151.9,
#     "sun_elevation": 36.3,
#     "updated": "2020-02-07T05:01:30Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 98,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182650_80_1063",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182650_80_1063/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200206_182650_80_1063/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -116.61454826350165,
#        33.26690606149163
#       ],
#       [
#        -116.57599596891907,
#        33.1129615652154
#       ],
#       [
#        -116.30146725237117,
#        33.1609800309707
#       ],
#       [
# ...
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -117.71854628272682,
#        34.433004085730055
#       ],
#       [
#        -117.7193549814051,
#        34.436140935009675
#       ],
#       [
#        -117.47067786578329,
#        34.47810830494831
#       ],
#       [
#        -117.46322660510964,
#        34.44833274708546
#       ],
#       [
#        -117.45429953292266,
#        34.41157715979352
#       ],
#       [
#        -117.70218515229996,
#        34.36954114017172
#       ],
#       [
#        -117.71654948513974,
#        34.42525873725758
#       ],
#       [
#        -117.71652692474527,
#        34.42526255952826
#       ],
#       [
#        -117.71854628272682,
#        34.433004085730055
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200205_163639_1053",
#    "properties": {
#     "acquired": "2020-02-05T16:36:39.750356Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 79,
#     "clear_percent": 98,
#     "cloud_cover": 0.02,
#     "cloud_percent": 0,
#     "columns": 8114,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 433908,
#     "origin_y": 3815271,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-05T20:21:11Z",
#     "quality_category": "standard",
#     "rows": 3973,
#     "satellite_id": "1053",
#     "shadow_percent": 0,
#     "snow_ice_percent": 2,
#     "strip_id": "3107334",
#     "sun_azimuth": 126.8,
#     "sun_elevation": 19.8,
#     "updated": "2020-02-06T04:32:17Z",
#     "view_angle": 3.9,
#     "visible_confidence_percent": 62,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163638_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163638_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163638_1053/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -117.68954851143076,
#        34.31815279032661
#       ],
#       [
#        -117.70340554270096,
#        34.37644685895904
#       ],
#       [
#        -117.45594191992836,
#        34.41833938795647
#       ],
#       [
#        -117.45329873916455,
#        34.40745657450341
#       ],
#       [
#        -117.45302343999406,
#        34.40750324528628
#       ],
#       [
#        -117.43955908367245,
#        34.35180347607472
#       ],
#       [
#        -117.68747660263301,
#        34.30983514852313
#       ],
#       [
#        -117.68954851143076,
#        34.31815279032661
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200205_163638_1053",
#    "properties": {
#     "acquired": "2020-02-05T16:36:38.82027Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 74,
#     "clear_percent": 91,
#     "cloud_cover": 0.09,
#     "cloud_percent": 0,
#     "columns": 8083,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 435327,
#     "origin_y": 3808638,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-05T20:21:11Z",
#     "quality_category": "standard",
#     "rows": 3972,
#     "satellite_id": "1053",
#     "shadow_percent": 1,
#     "snow_ice_percent": 8,
#     "strip_id": "3107334",
#     "sun_azimuth": 126.8,
#     "sun_elevation": 19.8,
#     "updated": "2020-02-06T04:31:38Z",
#     "view_angle": 3.9,
#     "visible_confidence_percent": 61,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163637_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163637_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163637_1053/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -117.42454199602675,
#        34.29182918591189
#       ],
#       [
#        -117.67209576975651,
#        34.24992948950591
#       ],
#       [
#        -117.68847073861431,
#        34.316554118605275
#       ],
#       [
#        -117.44113251370595,
#        34.35831249051577
#       ],
#       [
#        -117.43856324031456,
#        34.34768384020945
#       ],
#       [
#        -117.43799438096256,
#        34.34778016174716
#       ],
#       [
#        -117.42454199602675,
#        34.29182918591189
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200205_163637_1053",
#    "properties": {
#     "acquired": "2020-02-05T16:36:37.889658Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 72,
#     "clear_percent": 78,
#     "cloud_cover": 0.09,
#     "cloud_percent": 0,
#     "columns": 8091,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 436656,
#     "origin_y": 3801975,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-05T20:21:11Z",
#     "quality_category": "standard",
#     "rows": 3968,
#     "satellite_id": "1053",
#     "shadow_percent": 6,
#     "snow_ice_percent": 16,
#     "strip_id": "3107334",
#     "sun_azimuth": 126.8,
#     "sun_elevation": 19.9,
#     "updated": "2020-02-06T04:31:53Z",
#     "view_angle": 3.9,
#     "visible_confidence_percent": 65,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163636_1_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163636_1_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163636_1_1053/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -117.64397927183437,
#        34.132424346836785
#       ],
#       [
#        -117.65894887511199,
#        34.197553178435385
#       ],
#       [
#        -117.41150652992283,
#        34.23935670753935
#       ],
#       [
#        -117.4088355217595,
#        34.228068370971116
#       ],
#       [
#        -117.40816379333734,
#        34.22818213286566
#       ],
#       [
#        -117.39494981655734,
#        34.17287482910637
#       ],
#       [
#        -117.64357760709723,
#        34.13073467018203
#       ],
#       [
#        -117.64397927183437,
#        34.132424346836785
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200205_163636_1_1053",
#    "properties": {
#     "acquired": "2020-02-05T16:36:36.029485Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 79,
#     "clear_percent": 98,
#     "cloud_cover": 0.06,
#     "cloud_percent": 0,
#     "columns": 8105,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 439287,
#     "origin_y": 3788775,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-05T20:21:11Z",
#     "quality_category": "standard",
#     "rows": 3979,
#     "satellite_id": "1053",
#     "shadow_percent": 2,
#     "snow_ice_percent": 0,
#     "strip_id": "3107334",
#     "sun_azimuth": 126.8,
#     "sun_elevation": 20,
#     "updated": "2020-02-06T04:31:44Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 64,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163636_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163636_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163636_1053/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -117.40981141761961,
#        34.23219274658171
#       ],
#       [
#        -117.65768243037074,
#        34.190222447393495
#       ],
#       [
#        -117.67329501694967,
#        34.25692160433031
#       ],
#       [
#        -117.42615955502811,
#        34.29855691523491
#       ],
#       [
#        -117.42355304070404,
#        34.28771593643031
#       ],
#       [
#        -117.42297238620195,
#        34.28781423249139
#       ],
#       [
#        -117.40981141761961,
#        34.23219274658171
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200205_163636_1053",
#    "properties": {
#     "acquired": "2020-02-05T16:36:36.959571Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 70,
#     "clear_percent": 82,
#     "cloud_cover": 0.05,
#     "cloud_percent": 0,
#     "columns": 8083,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 438009,
#     "origin_y": 3795345,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-05T20:21:11Z",
#     "quality_category": "standard",
#     "rows": 3968,
#     "satellite_id": "1053",
#     "shadow_percent": 10,
#     "snow_ice_percent": 9,
#     "strip_id": "3107334",
#     "sun_azimuth": 126.8,
#     "sun_elevation": 19.9,
#     "updated": "2020-02-06T04:32:08Z",
#     "view_angle": 3.9,
#     "visible_confidence_percent": 62,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163635_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163635_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20200205_163635_1053/thumb"
#    },
#    "_permissions": [
#     "assets.udm:download",
#     "assets.analytic:download",
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_udm:download",
#     "assets.analytic_sr:download",
#     "assets.basic_udm2:download",
#     "assets.udm2:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -117.64084007533268,
#        34.11950876598139
#       ],
#       [
#        -117.64539285284367,
#        34.138442929258986
#       ],
#       [
#        -117.39675651269569,
#        34.18043678367827
#       ],
#       [
#        -117.39396367793607,
#        34.168747330686855
#       ],
#       [
#        -117.39385069186184,
#        34.16876648747383
#       ],
#       [
#        -117.38142186711468,
#        34.11850045393304
#       ],
#       [
#        -117.3803059595009,
#        34.11384717409295
#       ],
#       [
#        -117.62901869876974,
#        34.07162223800448
#       ],
#       [
#        -117.64084007533268,
#        34.11950876598139
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20200205_163635_1053",
#    "properties": {
#     "acquired": "2020-02-05T16:36:35.098873Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 79,
#     "clear_percent": 98,
#     "cloud_cover": 0.01,
#     "cloud_percent": 0,
#     "columns": 8145,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.5,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "light_haze_percent": 0,
#     "origin_x": 440493,
#     "origin_y": 3782235,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2020-02-05T20:21:11Z",
#     "quality_category": "standard",
#     "rows": 3987,
#     "satellite_id": "1053",
#     "shadow_percent": 0,
#     "snow_ice_percent": 2,
#     "strip_id": "3107334",
#     "sun_azimuth": 126.8,
#     "sun_elevation": 20,
#     "updated": "2020-02-06T04:32:09Z",
#     "view_angle": 3.9,
#     "visible_confidence_percent": 60,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %% [markdown]
# ### Image ID's Only

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(image_ids)
# Out:
# ['20200206_164211_0f24', '20200206_164211_1_0f24', '20200206_164210_0f24', '20200206_164212_0f24', '20200206_164209_0f24', '20200206_181042_0f3f', '20200206_181040_0f3f', '20200206_164213_0f24', '20200206_164208_0f24', '20200206_182707_40_1063', '20200206_182705_33_1063', '20200206_182703_25_1063', '20200206_182701_18_1063', '20200206_182659_10_1063', '20200206_182657_02_1063', '20200206_182654_95_1063', '20200206_182652_87_1063', '20200206_182650_80_1063', '20200206_205219_0f02', '20200206_205218_0f02', '20200206_205217_0f02', '20200206_205216_0f02', '20200206_205215_0f02', '20200206_205214_0f02', '20200206_205213_0f02', '20200206_205212_0f02', '20200206_205211_0f02', '20200206_181213_1010', '20200206_181212_1010', '20200206_181211_1010', '20200206_163348_0f3c', '20200206_181055_0f3f', '20200206_181053_0f3f', '20200206_181052_0f3f', '20200206_181050_0f3f', '20200206_181049_0f3f', '20200206_181048_0f3f', '20200206_181047_0f3f', '20200206_181045_0f3f', '20200206_181044_0f3f', '20200206_181043_0f3f', '20200206_181041_0f3f', '20200206_181038_0f3f', '20200206_181210_1010', '20200206_181619_1009', '20200206_181618_1009', '20200206_181617_1009', '20200206_181615_1009', '20200206_181614_1009', '20200206_181613_1009', '20200206_181612_1009', '20200206_181809_100c', '20200206_181807_100c', '20200206_181753_100c', '20200206_181751_100c', '20200206_164216_0f24', '20200206_164215_0f24', '20200206_164214_0f24', '20200206_164207_0f24', '20200206_164206_0f24', '20200206_164205_0f24', '20200206_164204_0f24', '20200206_164203_0f24', '20200206_164202_0f24', '20200206_164201_0f24', '20200206_164200_0f24', '20200206_164159_1_0f24', '20200206_164159_0f24', '20200206_164158_0f24', '20200206_164157_0f24', '20200206_164156_0f24', '20200206_164155_0f24', '20200206_164154_0f24', '20200206_164153_0f24', '20200206_164152_0f24', '20200206_164151_0f24', '20200206_163347_0f3c', '20200206_163346_0f3c', '20200206_163345_0f3c', '20200206_163344_0f3c', '20200206_163343_1_0f3c', '20200206_163343_0f3c', '20200206_163342_0f3c', '20200206_163341_0f3c', '20200206_163340_0f3c', '20200206_163339_0f3c', '20200206_163338_0f3c', '20200206_163337_0f3c', '20200206_163336_0f3c', '20200206_181812_100c', '20200206_181811_100c', '20200206_181810_100c', '20200206_181808_100c', '20200206_181806_100c', '20200206_181805_100c', '20200206_181755_100c', '20200206_181754_100c', '20200206_181752_100c', '20200206_181616_1009', '20200206_181216_1010', '20200206_181215_1010', '20200206_181214_1010', '20200206_181051_0f3f', '20200206_181046_0f3f', '20200206_181039_0f3f', '20200206_181037_0f3f', '20200206_164114_1054', '20200206_164112_1054', '20200206_164110_1_1054', '20200206_164109_1054', '20200206_164105_1054', '20200206_164103_1054', '20200206_164101_1054', '20200206_163709_0f44', '20200206_164115_1054', '20200206_164113_1054', '20200206_164111_1054', '20200206_164110_1054', '20200206_164108_1054', '20200206_164107_1054', '20200206_164106_1054', '20200206_164104_1054', '20200206_164102_1054', '20200206_164100_1054', '20200206_164052_1054', '20200206_164051_1054', '20200206_164050_1054', '20200206_164049_1054', '20200206_164048_1054', '20200206_164047_1054', '20200206_164046_1054', '20200206_164045_1054', '20200206_164044_1_1054', '20200206_164044_1054', '20200206_163735_0f44', '20200206_163710_0f44', '20200206_163708_0f44', '20200206_163707_0f44', '20200206_163706_1_0f44', '20200206_163706_0f44', '20200206_163705_0f44', '20200206_163704_0f44', '20200206_163703_0f44', '20200205_181927_0f31', '20200205_181805_1105', '20200205_181803_1105', '20200205_181608_0f15', '20200205_182151_1008', '20200205_182150_1008', '20200205_182149_1008', '20200205_182148_1008', '20200205_182147_1008', '20200205_182146_1008', '20200205_182145_1008', '20200205_182144_1008', '20200205_182143_1008', '20200205_180928_101b', '20200205_180927_101b', '20200205_180926_101b', '20200205_180925_101b', '20200205_180924_101b', '20200205_180923_101b', '20200205_180922_101b', '20200205_180921_101b', '20200205_181129_103b',  ...

# %%
# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# dict_keys(['analytic', 'analytic_dn', 'analytic_dn_xml', 'analytic_xml', 'basic_analytic', 'basic_analytic_dn', 'basic_analytic_dn_rpc', 'basic_analytic_dn_xml', 'basic_analytic_rpc', 'basic_analytic_xml', 'basic_udm', 'udm', 'visual', 'visual_xml'])

# %% [markdown]
# ## Step 4: Activation and Downloading

# %%
# This is "inactive" if the "visual" asset has not yet been activated; otherwise 'active'
print(result.json()['visual']['status'])
# Out:
# inactive

# %%
# Parse out useful links
links = result.json()[u"visual"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'visual' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %% [markdown]
# At this point, we wait for the activation status for the asset we are requesting to change from inactive to active. We can monitor this by polling the "status" of the asset:

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# active

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
